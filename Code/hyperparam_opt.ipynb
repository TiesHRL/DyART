102	-0.843	65	0.007	3	9
103	-1.063	77	0.009	4	11
104	-1.063	67	0.011	3	11
105	-0.678	78	0.010	3	8
106	-0.678	78	0.009	3	8
107	-0.678	78	0.011	4	8
108	-0.678	78	0.006	4	8
109	-0.678	78	0.012	5	8
110	-0.678	80	0.012	5	8
111	-0.741	79	0.012	5	7
112	-0.843	79	0.006	5	9
113	-0.678	79	0.012	4	8
114	-0.741	78	0.012	5	7
115	-0.678	80	0.012	4	8
116	-0.134	74	0.011	2	7
117	-0.134	61	0.007	2	7
118	-0.161	73	0.010	3	9
119	-0.161	64	0.012	2	9
120	-0.134	74	0.010	2	7
121	-0.134	75	0.012	2	7
122	-0.134	60	0.007	3	7
123	-0.119	60	0.010	3	8
124	-0.119	60	0.011	4	8
125	-0.161	60	0.009	3	9
126	-0.119	61	0.009	3	8
127	-0.119	60	0.011	4	8
128	-0.119	61	0.008	4	8
129	-0.119	61	0.007	4	8
130	-0.119	59	0.009	4	8
131	-0.455	57	0.011	2	7
132	-0.455	47	0.007	2	7
133	-0.330	56	0.010	3	9
134	-0.330	49	0.012	2	9
135	-0.455	57	0.010	2	7
136	-0.330	56	0.010	3	9
137	-0.330	50	0.013	2	9
138	-0.487	49	0.009	2	10
139	-0.330	50	0.013	2	9
140	-0.330	51	0.013	2	9
141	-0.330	50	0.013	3	9
142	-0.330	55	0.011	3	9
143	-0.487	56	0.010	2	10
144	-0.330	56	0.011	3	9
145	-0.330	56	0.010	3	9
"""

# Parsing the data into a dictionary
rows = data_str.strip().split('\n')
data = {"iter": [], "target": [], "max_depth": [], "max_weight": [], "min_size": [], "p": []}


for row in rows:
    cols = row.split()
    data["iter"].append(int(cols[0]))
    data["target"].append(float(cols[1]))
    data["max_depth"].append(float(cols[2]))
    data["max_weight"].append(float(cols[3]))
    data["min_size"].append(float(cols[4]))
    data["p"].append(float(cols[5]))

import pandas as pd
# Print the dictionary to verify
df = pd.DataFrame(data)

display(df)
# Out:
#      iter  target  max_depth  max_weight  min_size     p
# 0       1  -0.526       68.0       0.111       1.0   7.0
# 1       2  -0.513       31.0       0.023      10.0   8.0
# 2       3  -0.531       66.0       0.085      22.0  14.0
# 3       4  -0.531       39.0       0.133       2.0  14.0
# 4       6  -0.531      122.0       0.146      16.0  14.0
# ..    ...     ...        ...         ...       ...   ...
# 135   141  -0.330       50.0       0.013       3.0   9.0
# 136   142  -0.330       55.0       0.011       3.0   9.0
# 137   143  -0.487       56.0       0.010       2.0  10.0
# 138   144  -0.330       56.0       0.011       3.0   9.0
# 139   145  -0.330       56.0       0.010       3.0   9.0
#
# [140 rows x 6 columns]

# %%
# Provided data (first 5 rows)
data_str = """
1	-0.526	68	0.1108	1	7
2	-0.513	31	0.0229	10	8
3	-0.531	66	0.0854	22	14
4	-0.531	39	0.1329	2	14
5	-4.657	68	0.0882	8	5
6	-0.531	122	0.1456	16	14
7	-0.564	133	0.1352	5	2
8	-0.539	34	0.1329	6	9
9	-0.526	144	0.0846	35	7
10	-0.517	106	0.1268	2	15
11	-0.526	29	0.1050	10	7
12	-0.531	35	0.0522	7	14
13	-0.517	40	0.1490	7	10
14	-0.534	36	0.1500	13	11
15	-3.037	37	0.1500	11	4
16	-0.534	31	0.0868	10	11
17	-0.531	39	0.1500	11	14
18	-0.517	34	0.1455	15	15
111	-0.741	79	0.0120	5	7
112	-0.843	79	0.0065	5	9
113	-0.678	79	0.0120	4	8
114	-0.741	78	0.0120	5	7
115	-0.678	80	0.0120	4	8
116	-0.134	74	0.0108	2	7
117	-0.134	61	0.0072	2	7
118	-0.161	73	0.0098	3	9
119	-0.161	64	0.0117	2	9
120	-0.134	74	0.0099	2	7
121	-0.134	75	0.0124	2	7
122	-0.134	60	0.0067	3	7
123	-0.119	60	0.0098	3	8
124	-0.119	60	0.0109	4	8
125	-0.161	60	0.0089	3	9
126	-0.119	61	0.0093	3	8
127	-0.119	60	0.0114	4	8
128	-0.119	61	0.0085	4	8
129	-0.119	61	0.0067	4	8
130	-0.119	59	0.0093	4	8
131	-0.455	57	0.0111	2	7
132	-0.455	47	0.0074	2	7
133	-0.330	56	0.0101	3	9
134	-0.330	49	0.0121	2	9
135	-0.455	57	0.0102	2	7
136	-0.330	56	0.0098	3	9
137	-0.330	50	0.0128	2	9
138	-0.487	49	0.0092	2	10
139	-0.330	50	0.0128	2	9
140	-0.330	51	0.0128	2	9
141	-0.330	50	0.0128	3	9
142	-0.330	55	0.0115	3	9
143	-0.487	56	0.0098	2	10
144	-0.330	56	0.0109	3	9
145	-0.330	56	0.0096	3	9
"""

# Parsing the data into a dictionary
rows = data_str.strip().split('\n')
data = {"iter": [], "target": [], "max_depth": [], "max_weight": [], "min_size": [], "p": []}


for row in rows:
    cols = row.split()
    data["iter"].append(int(cols[0]))
    data["target"].append(float(cols[1]))
    data["max_depth"].append(float(cols[2]))
    data["max_weight"].append(float(cols[3]))
    data["min_size"].append(float(cols[4]))
    data["p"].append(float(cols[5]))

import pandas as pd
# Print the dictionary to verify
df = pd.DataFrame(data)

display(df)
# Out:
#      iter  target  max_depth  max_weight  min_size     p
# 0       1  -0.526       68.0      0.1108       1.0   7.0
# 1       2  -0.513       31.0      0.0229      10.0   8.0
# 2       3  -0.531       66.0      0.0854      22.0  14.0
# 3       4  -0.531       39.0      0.1329       2.0  14.0
# 4       5  -4.657       68.0      0.0882       8.0   5.0
# ..    ...     ...        ...         ...       ...   ...
# 140   141  -0.330       50.0      0.0128       3.0   9.0
# 141   142  -0.330       55.0      0.0115       3.0   9.0
# 142   143  -0.487       56.0      0.0098       2.0  10.0
# 143   144  -0.330       56.0      0.0109       3.0   9.0
# 144   145  -0.330       56.0      0.0096       3.0   9.0
#
# [145 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import parallel_coordinates
import numpy as np

# Sample data provided by the user
# data = {
#     "iter": range(1, 41),
#     "target": [-5.6, -5.6, -5.611, -5.611, -12.58, -5.611, -5.616, -5.864, -5.6, -5.785, -5.6, -5.785, -5.713, -5.785,
#                -5.713, -5.754, -5.235, -12.58, -5.235, -5.616, -5.575, -5.754, -5.973, -5.616, -5.235, -5.235, -5.6,
#                -5.864, -5.985, -5.6, -5.235, -5.616, -5.235, -5.616, -5.616, -5.235, -5.235, -5.235, -5.139, -5.235],
#     "max_depth": np.random.uniform(0, 0.15, 40),  # Sampled as random values for demonstration
#     "max_weight": np.random.uniform(1, 35, 40),    # Sampled as random values for demonstration
#     "min_size": np.random.uniform(5, 20, 40)      # Sampled as random values for demonstration
#     "p": 
# }
df = pd.DataFrame(data)

# Line Graph for Target Metric Over Iterations
plt.figure(figsize=(12, 6))
plt.plot(df['iter'], df['target'], marker='o')
plt.title('Target Metric Over Iterations')
plt.xlabel('Iteration')
plt.ylabel('Target Metric')
plt.grid(True)
plt.show()

# Scatter Plot for Hyperparameters vs Target Metric
fig, axs = plt.subplots(1, 4, figsize=(18, 6))
axs[0].scatter(df['max_depth'], df['target'])
axs[0].set_title('Max Depth vs Target Metric')
axs[0].set_xlabel('Max Depth')
axs[0].set_ylabel('Target Metric')

axs[1].scatter(df['max_weight'], df['target'])
axs[1].set_title('Max Weight vs Target Metric')
axs[1].set_xlabel('Max Weight')
axs[1].set_ylabel('Target Metric')

axs[2].scatter(df['min_size'], df['target'])
axs[2].set_title('Min Size vs Target Metric')
axs[2].set_xlabel('Min Size')
axs[2].set_ylabel('Target Metric')

axs[3].scatter(df['p'], df['target'])
axs[3].set_title('p vs Target Metric')
axs[3].set_xlabel('p')
axs[3].set_ylabel('Target Metric')
plt.show()


# # Heatmap for Hyperparameter Combinations
# heatmap_data = df.pivot(columns = ["max_depth", "max_weight", "target"])
# plt.figure(figsize=(9, 6))
# sns.heatmap(heatmap_data, annot=True)
# plt.title('Heatmap of Max Depth and Max Weight vs Target Metric')
# plt.xlabel('Max Weight')
# plt.ylabel('Max Depth')
# plt.show()

# # Box Plot for Distribution of Target Metrics
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='min_size', y='target', data=df)
# plt.title('Box Plot of Min Size vs Target Metric')
# plt.xlabel('Min Size')
# plt.ylabel('Target Metric')
# plt.show()

# 3D Surface Plot (requires additional libraries like mpl_toolkits)
# Note: This is just a placeholder as actual 3D plotting requires a different setup
plt.figure(figsize=(8, 6))
plt.title('3D Surface Plot Placeholder')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.text(0.5, 0.5, '3D Surface Plot (Requires mpl_toolkits)', ha='center', va='center')
plt.show()

# Histograms for Hyperparameter Distributions
fig, axs = plt.subplots(1, 4, figsize=(18, 6))
axs[0].hist(df['max_depth'], bins=10)
axs[0].set_title('Histogram of Max Depth')
axs[0].set_xlabel('Max Depth')
axs[0].set_ylabel('Frequency')

axs[1].hist(df['max_weight'], bins=10)
axs[1].set_title('Histogram of Max Weight')
axs[1].set_xlabel('Max Weight')
axs[1].set_ylabel('Frequency')

axs[2].hist(df['min_size'], bins=10)
axs[2].set_title('Histogram of Min Size')
axs[2].set_xlabel('Min Size')
axs[2].set_ylabel('Frequency')

axs[3].hist(df['p'], bins=10)
axs[3].set_title('Histogram of p')
axs[3].set_xlabel('p')
axs[3].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from pandas.plotting import parallel_coordinates

plt.figure(figsize=(12, 6))
parallel_coordinates(df, 'target')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs[0, 0].scatter(df['max_depth'], df['target'])
axs[0, 1].scatter(df['max_weight'], df['target'])
axs[1, 0].scatter(df['min_size'], df['target'])
axs[1, 1].scatter(df['p'], df['target'])
# Set titles and labels for each subplot
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Assuming df is your DataFrame
# df = pd.DataFrame(your_data)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(df['max_weight'], df['max_depth'], df['p'], c=df['target'], cmap='viridis')

# Adding a color bar
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Target Value')

# Setting labels and title
ax.set_xlabel('Max Weight')
ax.set_ylabel('Max Depth')
ax.set_zlabel('p')
ax.set_title('3D Scatter Plot with p Hyperparameter Color Mapping')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame
# df = pd.DataFrame(your_data)

# Create a pairplot
pairplot = sns.pairplot(df, vars=['max_depth', 'max_weight', 'min_size', 'p'], 
                        palette='viridis', hue='target')

# Enhancing the plot
pairplot.fig.suptitle('Pairplot of Hyperparameters with Target Metric Coloring', fontsize=16)
pairplot.fig.subplots_adjust(top=0.95)  # Adjusting the title position

plt.show()

# %%
df

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
# df = pd.read_excel('../retrainings.xlsx')

# Plot the performance metric over time
plt.figure(figsize=(10, 6))
plt.plot(df['iter'], df['Performance_Metric'], marker='o')

# Highlight changepoints
for cp in df['Changepoint'].dropna().unique():
    plt.axvline(x=cp, color='red', linestyle='--', label='Changepoint')

plt.xlabel('Time')
plt.ylabel('Performance Metric')
plt.title('Performance Metric over Time with Changepoints')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tiesh\Documents\Thesis_CD\DyART\.venv\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\tiesh\Documents\Thesis_CD\DyART\.venv\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\tiesh\Documents\Thesis_CD\DyART\.venv\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'iter'
#
# The above exception was the direct cause of the following exception:
# ...

# %%
df1 = df.drop('iter', axis=1)

# %%
from skopt.plots import plot_objective
from skopt.space import Space
from skopt.utils import create_result
import pandas as pd
import matplotlib.pyplot as plt
from skopt import Optimizer
from skopt.space import Integer, Real


# Define the search space
space = Space([
    Real(min(df['max_depth']), max(df['max_depth']), name='max_depth'),
    Real(min(df['max_weight']), max(df['max_weight']), name='max_weight'),
    Real(min(df['min_size']), max(df['min_size']), name='min_size'),  # example range, adjust as necessary
    Integer(min(df['p']), max(df['p']), name='p')
])

# Create an optimizer object
opt = Optimizer(space)

# Assume that df['target'] are the function values and df.drop('target', axis=1) are the points
for i in range(len(df1)):
    opt.tell(df1.drop('target', axis=1).iloc[i].tolist(), -df1['target'].iloc[i])

# Use plot_objective
plot_objective(opt.get_result())
plt.show()

# %%
df[df['target']==-5.139]
# Out:
#     iter  target  max_depth  max_weight  min_size    p
# 36    39  -5.139      41.62     0.08838     8.977  9.0

# %%
opt = Optimizer(space)
for i in range(len(df1)):
    # Negate the target value for maximization
    opt.tell(df1.drop('target', axis=1).iloc[i].tolist(), -df1['target'].iloc[i])

# Use plot_objective, note that we also negate the 'space.target' to plot it correctly
_ = plot_objective(result=opt.get_result(), sample_source='expected_minimum_random')
plt.show()

# %%
opt = Optimizer(space)
for i in range(len(df1)):
    # Negate the target value for maximization
    opt.tell(df1.drop('target', axis=1).iloc[i].tolist(), -df1['target'].iloc[i])

# Use plot_objective, note that we also negate the 'space.target' to plot it correctly
_ = plot_objective(result=opt.get_result(), sample_source='result')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is a DataFrame with your optimization results
# and it includes a 'target' column with the performance metric
# and an 'iter' column with the iteration number.

# Sort the DataFrame by iteration just in case it's not already sorted
# df = df.sort_values('iter')
df_first = df[df['iter']<41]
# Plot the learning curve
plt.figure(figsize=(10, 6))
plt.plot(df_first['iter'], df_first['target'], marker='o', linestyle='-', color='blue')
plt.title('Learning Curve')
plt.xlabel('Iteration')
plt.ylabel('Performance Metric')
plt.grid(True)
plt.show()

# %%
df_first
# Out:
#     iter  target  max_depth  max_weight  min_size     p
# 0      1  -5.600      68.38     0.11080     1.006  10.0
# 1      2  -5.600      30.55     0.02293    10.130  10.0
# 2      3  -5.611      65.55     0.08543    21.540  15.0
# 3      4  -5.611      38.62     0.13290     2.342  15.0
# 4      6  -5.611     122.10     0.14560    16.360  15.0
# 5      7  -5.616     132.70     0.13520     5.167   6.0
# 6      8  -5.864      33.78     0.13290     5.819  11.0
# 7      9  -5.600     144.10     0.08464    34.900  10.0
# 8     10  -5.785     106.10     0.12680     1.896  16.0
# 9     11  -5.600     142.70     0.02351    34.750  10.0
# 10    12  -5.785      37.15     0.01000     7.104  16.0
# 11    13  -5.713      33.75     0.09810    12.860  13.0
# 12    14  -5.785      28.40     0.10380     7.986  16.0
# 13    15  -5.713      27.20     0.15000    14.290  13.0
# 14    16  -5.754     126.50     0.02635    11.180  12.0
# 15    17  -5.235     130.30     0.08550    10.700   5.0
# ...
