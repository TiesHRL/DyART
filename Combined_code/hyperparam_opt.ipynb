# %%
# Provided data (first 5 rows)
data_str = """
1	1.0550	68	0.11	1	7
2	1.0450	31	0.02	10	8
3	1.0040	66	0.09	22	14
4	1.0040	39	0.13	2	14
5	0.9628	68	0.09	8	5
6	1.0040	122	0.15	16	14
7	1.0440	133	0.14	5	2
8	1.0420	34	0.13	6	9
9	1.0550	144	0.08	35	7
10	1.0210	106	0.13	2	15
11	1.0550	145	0.15	35	7
12	0.9989	145	0.14	35	4
13	1.0550	145	0.15	34	7
14	1.0450	144	0.04	34	8
15	1.0450	70	0.04	1	8
16	1.0450	145	0.15	35	8
17	0.6717	71	0.02	1	6
18	1.0450	68	0.11	2	8
19	0.6717	67	0.11	2	6
20	1.0550	146	0.13	35	7
21	0.6717	144	0.08	34	6
22	1.0150	57	0.08	21	17
23	1.0070	43	0.07	28	19
24	0.9989	27	0.09	25	4
25	1.0550	68	0.11	1	7
26	1.0550	145	0.14	36	7
27	0.9930	35	0.05	40	13
28	1.0550	145	0.02	36	7
29	1.0550	145	0.03	35	7
30	0.9989	125	0.03	2	4
31	1.0130	133	0.12	5	3
32	1.0550	136	0.07	21	7
33	1.0550	145	0.05	36	7
34	1.0550	137	0.09	20	7
35	1.0550	146	0.04	34	7
36	1.0550	145	0.09	35	7
37	1.0450	30	0.14	9	8
38	1.0450	137	0.10	21	8
39	1.0550	143	0.07	36	7
40	1.0450	146	0.04	34	8
"""
#  Parsing the data into a dictionary
rows = data_str.strip().split('\n')
data = {"iter": [], "target": [], "max_depth": [], "max_weight": [], "min_size": [], "p": []}


for row in rows:
    cols = row.split()
    data["iter"].append(int(cols[0]))
    data["target"].append(float(cols[1]))
    data["max_depth"].append(float(cols[2]))
    data["max_weight"].append(float(cols[3]))
    data["min_size"].append(float(cols[4]))
    data["p"].append(float(cols[5]))

import pandas as pd
# Print the dictionary to verify
df = pd.DataFrame(data)

display(df)
# Out:
#     iter  target  max_depth  max_weight  min_size     p
# 0      1  1.0550       68.0        0.11       1.0   7.0
# 1      2  1.0450       31.0        0.02      10.0   8.0
# 2      3  1.0040       66.0        0.09      22.0  14.0
# 3      4  1.0040       39.0        0.13       2.0  14.0
# 4      5  0.9628       68.0        0.09       8.0   5.0
# 5      6  1.0040      122.0        0.15      16.0  14.0
# 6      7  1.0440      133.0        0.14       5.0   2.0
# 7      8  1.0420       34.0        0.13       6.0   9.0
# 8      9  1.0550      144.0        0.08      35.0   7.0
# 9     10  1.0210      106.0        0.13       2.0  15.0
# 10    11  1.0550      145.0        0.15      35.0   7.0
# 11    12  0.9989      145.0        0.14      35.0   4.0
# 12    13  1.0550      145.0        0.15      34.0   7.0
# 13    14  1.0450      144.0        0.04      34.0   8.0
# 14    15  1.0450       70.0        0.04       1.0   8.0
# 15    16  1.0450      145.0        0.15      35.0   8.0
# ...

# %%
# Provided data (first 5 rows)
data_str = """
1	1.26	68	36	1
2	1.242	52	8	3
data = {"iter": [], "target": [], "max_depth": [], "min_size": [], "p": []}


for row in rows:
    cols = row.split()
    data["iter"].append(int(cols[0]))
    data["target"].append(float(cols[1]))
    data["max_depth"].append(float(cols[2]))
    data["min_size"].append(float(cols[3]))
    data["p"].append(float(cols[4]))

import pandas as pd
# Print the dictionary to verify
df = pd.DataFrame(data)

display(df)
# Out:
#      iter  target  max_depth  min_size     p
# 0       1   1.260       68.0      36.0   1.0
# 1       2   1.242       52.0       8.0   3.0
# 2       3   1.261       36.0      18.0   9.0
# 3       4   1.205       85.0      22.0  14.0
# 4       5   1.271       39.0      44.0   2.0
# ..    ...     ...        ...       ...   ...
# 115   116   1.261       35.0      18.0   6.0
# 116   117   1.260       46.0      50.0   1.0
# 117   118   1.261       37.0      18.0   6.0
# 118   119   1.252       35.0      21.0   7.0
# 119   120   1.242       42.0      44.0   3.0
#
# [120 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import parallel_coordinates
import numpy as np

# Sample data provided by the user
# data = {
#     "iter": range(1, 41),
#     "target": [-5.6, -5.6, -5.611, -5.611, -12.58, -5.611, -5.616, -5.864, -5.6, -5.785, -5.6, -5.785, -5.713, -5.785,
#                -5.713, -5.754, -5.235, -12.58, -5.235, -5.616, -5.575, -5.754, -5.973, -5.616, -5.235, -5.235, -5.6,
#                -5.864, -5.985, -5.6, -5.235, -5.616, -5.235, -5.616, -5.616, -5.235, -5.235, -5.235, -5.139, -5.235],
#     "max_depth": np.random.uniform(0, 0.15, 40),  # Sampled as random values for demonstration
#     "max_weight": np.random.uniform(1, 35, 40),    # Sampled as random values for demonstration
#     "min_size": np.random.uniform(5, 20, 40)      # Sampled as random values for demonstration
#     "p": 
# }
df = pd.DataFrame(data)

# Line Graph for Target Metric Over Iterations
plt.figure(figsize=(12, 6))
plt.plot(df['iter'], df['target'], marker='o')
plt.title('Target Metric Over Iterations')
plt.xlabel('Iteration')
plt.ylabel('Target Metric')
plt.grid(True)
plt.show()

# Scatter Plot for Hyperparameters vs Target Metric
fig, axs = plt.subplots(1, 4, figsize=(18, 6))
axs[0].scatter(df['max_depth'], df['target'])
axs[0].set_title('Max Depth vs Target Metric')
axs[0].set_xlabel('Max Depth')
axs[0].set_ylabel('Target Metric')

axs[1].scatter(df['max_weight'], df['target'])
axs[1].set_title('Max Weight vs Target Metric')
axs[1].set_xlabel('Max Weight')
axs[1].set_ylabel('Target Metric')

axs[2].scatter(df['min_size'], df['target'])
axs[2].set_title('Min Size vs Target Metric')
axs[2].set_xlabel('Min Size')
axs[2].set_ylabel('Target Metric')

axs[3].scatter(df['p'], df['target'])
axs[3].set_title('p vs Target Metric')
axs[3].set_xlabel('p')
axs[3].set_ylabel('Target Metric')
plt.show()


# # Heatmap for Hyperparameter Combinations
# heatmap_data = df.pivot(columns = ["max_depth", "max_weight", "target"])
# plt.figure(figsize=(9, 6))
# sns.heatmap(heatmap_data, annot=True)
# plt.title('Heatmap of Max Depth and Max Weight vs Target Metric')
# plt.xlabel('Max Weight')
# plt.ylabel('Max Depth')
# plt.show()

# # Box Plot for Distribution of Target Metrics
# plt.figure(figsize=(12, 6))
# sns.boxplot(x='min_size', y='target', data=df)
# plt.title('Box Plot of Min Size vs Target Metric')
# plt.xlabel('Min Size')
# plt.ylabel('Target Metric')
# plt.show()

# 3D Surface Plot (requires additional libraries like mpl_toolkits)
# Note: This is just a placeholder as actual 3D plotting requires a erent setup
plt.figure(figsize=(8, 6))
plt.title('3D Surface Plot Placeholder')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.text(0.5, 0.5, '3D Surface Plot (Requires mpl_toolkits)', ha='center', va='center')
plt.show()

# Histograms for Hyperparameter Distributions
fig, axs = plt.subplots(1, 4, figsize=(18, 6))
axs[0].hist(df['max_depth'], bins=10)
axs[0].set_title('Histogram of Max Depth')
axs[0].set_xlabel('Max Depth')
axs[0].set_ylabel('Frequency')

axs[1].hist(df['max_weight'], bins=10)
axs[1].set_title('Histogram of Max Weight')
axs[1].set_xlabel('Max Weight')
axs[1].set_ylabel('Frequency')

axs[2].hist(df['min_size'], bins=10)
axs[2].set_title('Histogram of Min Size')
axs[2].set_xlabel('Min Size')
axs[2].set_ylabel('Frequency')

axs[3].hist(df['p'], bins=10)
axs[3].set_title('Histogram of p')
axs[3].set_xlabel('p')
axs[3].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from pandas.plotting import parallel_coordinates

plt.figure(figsize=(12, 6))
parallel_coordinates(df, 'target')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs[0, 0].scatter(df['max_depth'], df['target'])
axs[0, 1].scatter(df['max_weight'], df['target'])
axs[1, 0].scatter(df['min_size'], df['target'])
axs[1, 1].scatter(df['p'], df['target'])
# Set titles and labels for each subplot
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Assuming df is your DataFrame
# df = pd.DataFrame(your_data)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(df['max_weight'], df['max_depth'], df['p'], c=df['target'], cmap='viridis')

# Adding a color bar
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Target Value')

# Setting labels and title
ax.set_xlabel('Max Weight')
ax.set_ylabel('Max Depth')
ax.set_zlabel('p')
ax.set_title('3D Scatter Plot with p Hyperparameter Color Mapping')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame
# df = pd.DataFrame(your_data)

# Create a pairplot
pairplot = sns.pairplot(df, vars=['max_depth', 'max_weight', 'min_size', 'p'], 
                        palette='viridis', hue='target')

# Enhancing the plot
pairplot.fig.suptitle('Pairplot of Hyperparameters with Target Metric Coloring', fontsize=16)
pairplot.fig.subplots_adjust(top=0.95)  # Adjusting the title position

plt.show()

# %%
df
# Out:
#      iter  target  max_depth  max_weight  min_size     p
# 0       1  1.0550       68.0        0.11       1.0   7.0
# 1       2  1.0450       31.0        0.02      10.0   8.0
# 2       3  1.0040       66.0        0.09      22.0  14.0
# 3       4  1.0040       39.0        0.13       2.0  14.0
# 4       5  0.9628       68.0        0.09       8.0   5.0
# ..    ...     ...        ...         ...       ...   ...
# 155   156  1.0550      145.0        0.09      35.0   7.0
# 156   157  1.0550      146.0        0.11      36.0   7.0
# 157   158  1.0550      146.0        0.04      32.0   7.0
# 158   159  1.0550      143.0        0.07      36.0   7.0
# 159   160  1.0170      146.0        0.09      38.0   8.0
#
# [160 rows x 6 columns]

# %%
from skopt.plots import plot_objective
from skopt.space import Space
from skopt.utils import create_result
import pandas as pd
import matplotlib.pyplot as plt
from skopt import Optimizer
from skopt.space import Integer, Real

df1 = df.drop('iter', axis=1)
# Define the search space
space = Space([
    Integer(min(df['max_depth']), max(df['max_depth']), name='max_depth'),
    Real(min(df['max_weight']), max(df['max_weight']), name='max_weight'),
    Integer(min(df['min_size']), max(df['min_size']), name='min_size'),  # example range, adjust as necessary
    Integer(min(df['p']), max(df['p']), name='p')
])

# Create an optimizer object
opt = Optimizer(space)

# Assume that df['target'] are the function values and df.drop('target', axis=1) are the points
for i in range(len(df1)):
    opt.tell(df1.drop('target', axis=1).iloc[i].tolist(), -df1['target'].iloc[i])

# Use plot_objective
plot_objective(opt.get_result())
plt.show()

# %%
from cProfile import label
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is a DataFrame with your optimization results
# and it includes a 'target' column with the performance metric
# and an 'iter' column with the iteration number.

# Sort the DataFrame by iteration just in case it's not already sorted
# df = df.sort_values('iter')
df_1 = df[df['iter']<41]
df_1.set_index(df_1['iter'], inplace=True)

df_2 = df[df['iter']>40][df['iter']<=80]
df_2.set_index(df_2['iter'], inplace=True)
df_2.index = [i for i in range(1, 1+len(df_2))]

df_3 = df[df['iter']>80][df['iter']<=120]
# df_3.reset_index(drop=True)
df_3.index = [i for i in range(1, 1+len(df_3))]

# df_4 = df_[df_['iter']>120]
# # df_4.reset_index(drop=True)
# df_4.index = [i for i in range(1,1+len(df_4))]
# # Plot the learning curve
plt.figure(figsize=(10, 6))
plt.plot(df_1.index, df_1['target'], marker='o', linestyle='-', label = "ART tu")
plt.plot(df_2.index, df_2['target'], marker='o', linestyle='-', label = "ART tr")
plt.plot(df_3.index, df_3['target'], marker='o', linestyle='-', label = "ART")
# plt.plot(df_4.index, df_4['target'], marker='o', linestyle='-', label = "ARXT")
plt.legend()
plt.title('Learning Curves')
plt.xlabel('Iteration')
plt.ylabel('Performance Metric')
plt.grid(True)
plt.show()
# Out:
# C:\Users\tiesh\AppData\Local\Temp\ipykernel_38264\1447382141.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2 = df[df['iter']>40][df['iter']<=80]
# C:\Users\tiesh\AppData\Local\Temp\ipykernel_38264\1447382141.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_3 = df[df['iter']>80][df['iter']<=120]

# %% [markdown]
# SPLITS

# %%
# Provided data (first 5 rows)
data_str = """
1	1.2480	65	0.13	1	6
2	1.2480	54	0.08	1	6
3	1.2820	64	0.11	1	8
4	1.2820	56	0.14	1	8
5	1.2480	65	0.11	1	6
6	1.2820	64	0.11	1	8
7	1.2820	57	0.14	1	8
8	1.2040	56	0.14	1	9
9	1.2820	57	0.14	1	8
10	1.2820	57	0.10	1	8
11	1.2580	56	0.13	1	7
12	1.2820	64	0.12	1	8
13	1.2820	64	0.09	1	8
14	1.2820	57	0.14	1	8
15	1.2040	64	0.09	1	9
16	0.9623	61	0.13	1	7
17	0.9623	50	0.09	1	7
18	0.9763	60	0.12	1	9
19	0.9763	53	0.14	1	9
20	0.9623	61	0.12	1	7
21	0.9763	60	0.11	1	9
22	0.9763	54	0.15	1	9
23	0.9689	53	0.13	1	10
24	0.9548	54	0.15	1	8
25	0.9689	59	0.08	1	10
197	1.2450	24	0.17	1	9
198	1.2490	28	0.22	1	11
199	1.2490	25	0.27	1	11
200	1.2220	29	0.23	1	8
201	1.2730	21	0.18	1	12
202	1.2730	21	0.18	1	12
203	1.2730	21	0.17	1	12
204	1.2730	22	0.29	1	12
205	1.2680	21	0.29	1	13
206	1.2730	22	0.15	1	12
207	1.2680	23	0.29	1	13
208	1.2730	22	0.15	1	12
209	1.2680	39	0.22	1	13
210	1.2490	39	0.29	1	11
"""
#  Parsing the data into a dictionary
rows = data_str.strip().split('\n')
data = {"iter": [], "target": [], "max_depth": [], "max_weight": [], "min_size": [], "p": []}


for row in rows:
    cols = row.split()
    data["iter"].append(int(cols[0]))
    data["target"].append(float(cols[1]))
    data["max_depth"].append(float(cols[2]))
    data["max_weight"].append(float(cols[3]))
    data["min_size"].append(float(cols[4]))
    data["p"].append(float(cols[5]))

import pandas as pd
# Print the dictionary to verify
df_split = pd.DataFrame(data)

display(df_split)
# Out:
#      iter  target  max_depth  max_weight  min_size     p
# 0       1   1.248       65.0        0.13       1.0   6.0
# 1       2   1.248       54.0        0.08       1.0   6.0
# 2       3   1.282       64.0        0.11       1.0   8.0
# 3       4   1.282       56.0        0.14       1.0   8.0
# 4       5   1.248       65.0        0.11       1.0   6.0
# ..    ...     ...        ...         ...       ...   ...
# 205   206   1.273       22.0        0.15       1.0  12.0
# 206   207   1.268       23.0        0.29       1.0  13.0
# 207   208   1.273       22.0        0.15       1.0  12.0
# 208   209   1.268       39.0        0.22       1.0  13.0
# 209   210   1.249       39.0        0.29       1.0  11.0
#
# [210 rows x 6 columns]

# %%
# Provided data (first 5 rows)
data_str = """
1	1.377	37	50	1
2	1.373	34	35	2
3	1.373	32	40	2
4	1.373	40	42	2
5	1.377	32	54	1
6	1.377	37	54	1
7	1.373	35	52	2
8	1.373	41	38	2
9	1.076	33	35	3
10	1.373	44	50	2
11	1.373	38	42	2
12	1.373	32	54	2
13	1.377	36	35	1
14	1.377	35	34	1
15	1.373	37	52	2
16	1.338	35	57	1
17	1.338	33	39	1
18	1.338	30	45	1
19	1.338	38	48	1
20	1.338	30	61	1
21	1.338	48	65	1
22	1.338	48	35	1
23	1.338	26	35	1
24	1.338	48	65	1
25	1.338	26	65	1
26	1.338	48	35	1
27	1.338	26	35	1
28	1.338	48	65	1
29	1.338	48	35	1
30	1.338	26	65	1
31	1.241	33	65	1
32	1.241	31	45	1
33	1.241	28	52	1
34	1.241	36	54	1
35	1.241	29	70	1
36	1.241	45	74	1
37	1.241	45	40	1
38	1.241	25	40	1
39	1.241	45	74	1
40	1.241	25	74	1
41	1.241	45	40	1
42	1.241	25	40	1
43	1.241	46	74	1
44	1.241	45	40	1
45	1.241	25	74	1
46	0.681	31	74	1
47	0.681	29	51	1
48	0.681	27	59	1
49	0.681	34	62	1
50	0.681	27	80	1
51	0.681	43	84	1
52	0.681	43	46	1
53	0.681	23	46	1
54	0.681	43	84	1
55	0.681	23	84	1
56	0.681	43	46	1
57	0.681	23	46	1
58	0.681	43	84	1
59	0.681	43	46	1
60	0.681	23	84	1
61	1.283	29	84	1
62	1.283	27	58	1
63	1.283	25	67	1
64	1.283	32	70	1
65	1.283	26	91	1
66	1.283	40	96	1
67	1.283	40	52	1
68	1.283	22	52	1
69	1.283	40	96	1
70	1.283	22	96	1
71	1.283	40	52	1
72	1.283	22	52	1
73	1.283	40	96	1
74	1.283	40	52	1
75	1.283	22	96	1
76	0.680	28	95	1
77	0.680	26	66	1
78	0.680	24	76	1
79	0.680	30	80	1
80	0.680	24	103	1
81	0.680	38	109	1
82	0.680	38	59	1
83	0.680	20	59	1
84	0.680	38	109	1
85	0.680	21	109	1
86	0.680	37	59	1
87	0.680	20	59	1
88	0.680	20	109	1
89	0.680	37	59	1
90	0.680	37	109	1
91	0.663	27	108	1
92	0.663	25	75	1
93	0.663	23	86	1
94	0.663	29	90	1
95	0.663	23	117	1
96	0.663	36	124	1
97	0.663	36	67	1
98	0.663	20	67	1
99	0.663	36	123	1
100	0.663	36	67	1
101	0.663	20	123	1
102	0.663	20	67	1
103	0.663	20	124	1
104	0.663	36	67	1
105	0.663	36	123	1
"""
#  Parsing the data into a dictionary
rows = data_str.strip().split('\n')
data = {"iter": [], "target": [], "max_depth": [], "min_size": [], "p": []}


for row in rows:
    cols = row.split()
    data["iter"].append(int(cols[0]))
    data["target"].append(float(cols[1]))
    data["max_depth"].append(float(cols[2]))
    data["min_size"].append(float(cols[3]))
    data["p"].append(float(cols[4]))

import pandas as pd
# Print the dictionary to verify
df_split = pd.DataFrame(data)

display(df_split)
# Out:
#      iter  target  max_depth  min_size    p
# 0       1   1.377       37.0      50.0  1.0
# 1       2   1.373       34.0      35.0  2.0
# 2       3   1.373       32.0      40.0  2.0
# 3       4   1.373       40.0      42.0  2.0
# 4       5   1.377       32.0      54.0  1.0
# ..    ...     ...        ...       ...  ...
# 100   101   0.663       20.0     123.0  1.0
# 101   102   0.663       20.0      67.0  1.0
# 102   103   0.663       20.0     124.0  1.0
# 103   104   0.663       36.0      67.0  1.0
# 104   105   0.663       36.0     123.0  1.0
#
# [105 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is a DataFrame with your optimization results
# and it includes a 'target' column with the performance metric
# and an 'iter' column with the iteration number.

# Sort the DataFrame by iteration just in case it's not already sorted
# df = df.sort_values('iter')
df_first = df_split[df_split['iter']<106]
df_first.set_index(df_first['iter'], inplace=True)

# df_second = df_split[df_split['iter']>105]
# df_second.set_index(df_second['iter'], inplace=True)
# df_second.index = df_first.index
# Plot the learning curve
plt.figure(figsize=(10, 6))
plt.plot(df_first.index, df_first['target'], marker='o', linestyle='-', color='blue', label="ART tu")
# plt.plot(df_second.index, df_second['target'], marker='o', linestyle='-', color='red', label="ARXT t")
plt.title('Retuning Learning Curves')
plt.xlabel('Iteration')
plt.ylabel('Performance Metric')
plt.legend()
plt.grid(True)
plt.show()
